# %% [markdown]
# <a href="https://colab.research.google.com/github/Jacofeldman/Metodos1_JacoboFeldman/blob/main/Tarea2/Derivada8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sym
import math
import numpy as np
import matplotlib.pyplot as plt

#c)
# Definir la función f(x) = sqrt(tan(x))
def f(x):
    return np.sqrt(np.tan(x))

# Definir el cálculo de la derivada progresiva de segundo orden
def forward_difference(f, x, h):
    return (-f(x + 2*h) + 4*f(x + h) - 3*f(x)) / (2*h)

# Parámetros
h = 0.01
x_values = np.arange(0.1, 1.1 + h, h)
derivatives_forward = [forward_difference(f, x, h) for x in x_values]

# Graficar las derivadas progresivas
plt.figure(figsize=(8, 6))
plt.scatter(x_values, derivatives_forward, label="Derivada progresiva de $f(x) = \sqrt{\\tan(x)}$", color='pink',s=10)
plt.title("Estimación de la derivada progresiva de $f(x) = \sqrt{\\tan(x)}$")
plt.xlabel("x")
plt.ylabel("f'(x)")
plt.legend()
plt.grid(True)
plt.show()

# %%
#d)

# Definir el cálculo de la derivada central de segundo orden
def central_difference(f, x, h):
    return (f(x + h) - f(x - h)) / (2 * h)

# Parámetros
h = 0.01
x_values = np.arange(0.1, 1.1 + h, h)
derivatives_central = [central_difference(f, x, h) for x in x_values]

# Graficar las derivadas centrales
plt.figure(figsize=(8, 6))
plt.scatter(x_values, derivatives_central, label="Derivada central de $f(x) = \sqrt{\\tan(x)}$", color='purple',s=10)
plt.title("Estimación de la derivada central de $f(x) = \sqrt{\\tan(x)}$")
plt.xlabel("x")
plt.ylabel("f'(x)")
plt.grid(True)
plt.legend()
plt.show()

# %%
#e)
def derivative_real(x):
    return 1/(2*np.sqrt(np.tan(x))*(np.cos(x))**2)
derivative_real_values = [derivative_real(x) for x in x_values]

# Graficar las derivadas reales
plt.figure(figsize=(8, 6))
plt.scatter(x_values, derivative_real_values, label="Derivada real de $f(x) = \sqrt{\\tan(x)}$", color='g',s=10)
plt.title("Derivada real de $f(x) = \sqrt{\\tan(x)}$")
plt.xlabel("x")
plt.ylabel("f'(x)")
plt.grid(True)
plt.legend()
plt.show()

# %%
#f)
ErrorProgresivo = np.abs([derivatives_forward[i] - derivative_real(x_values[i]) for i in range(len(x_values))]) # Calculate error at each point in x_values
ErrorCentral = np.abs([derivatives_central[i] - derivative_real(x_values[i]) for i in range(len(x_values))]) # Calculate error at each point in x_values
plt.scatter(x_values, ErrorProgresivo, label="Error progresivo", color='r',s=5)
plt.scatter(x_values, ErrorCentral, label="Error central", color='b',s=5)
plt.legend()
plt.xlabel('x')
plt.ylabel('Error')
plt.title('Error progresivo y central')
plt.grid(True)
plt.show()

# %% [markdown]
# Es de mismo orden O(h^2) las dos pero la central se nota que da un error menor debido a que calcula los valores usando informacion simetrica alrededor del punto x
