# %% [markdown]
# <a href="https://colab.research.google.com/github/Jacofeldman/Metodos1_JacoboFeldman/blob/main/Tarea3/Integracion_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# Método del trapecio
def trapezoidal_rule(f, a, b, n):
    h = (b - a) / n
    x = np.linspace(a, b, n+1)
    y = f(x)
    integral = h * (0.5 * y[0] + 0.5 * y[-1] + np.sum(y[1:-1]))
    return integral,x,y


f = lambda x: np.exp(-x**2)

error_tolerance = 0.005
f_prime_max_value = 2
a = 0
b = 1


n_min = math.sqrt(((b - a)**3 * f_prime_max_value) / (12 * error_tolerance))


n_required = math.ceil(n_min)


integral_value,x,y = trapezoidal_rule(f, a, b, n_required)

print(f"Número de puntos necesarios (n): {n_required}")
print(f"Valor aproximado de la integral: {integral_value:.5f}")
# Out:
# Número de puntos necesarios (n): 6
# Valor aproximado de la integral: 0.74512

# %%
# Out:
# (0.7468241328124271, 8.291413475940725e-15)
